# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %% [markdown]
# ### Load Dataset

# %%
# train_df = pd.read_csv('fashion-mnist_train.csv')
# test_df = pd.read_csv('fashion-mnist_test.csv')


from tensorflow.keras.datasets import fashion_mnist

# Load the data directly
(train_images, train_labels), (test_images, test_labels) = fashion_mnist.load_data()

# Optionally, you can store them in DataFrames for easier manipulation
import pandas as pd

train_df = pd.DataFrame(train_images.reshape(train_images.shape[0], -1))
test_df = pd.DataFrame(test_images.reshape(test_images.shape[0], -1))

# Show the dataframes
train_df.head(), test_df.head()

# %%
train_df.shape
# Out:
# (60000, 785)

# %%
test_df.shape
# Out:
# (10000, 785)

# %%
train_df.describe()
# Out:
#               label        pixel1        pixel2        pixel3        pixel4  \
# count  60000.000000  60000.000000  60000.000000  60000.000000  60000.000000
# mean       4.500000      0.000900      0.006150      0.035333      0.101933
# std        2.872305      0.094689      0.271011      1.222324      2.452871
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%        2.000000      0.000000      0.000000      0.000000      0.000000
# 50%        4.500000      0.000000      0.000000      0.000000      0.000000
# 75%        7.000000      0.000000      0.000000      0.000000      0.000000
# max        9.000000     16.000000     36.000000    226.000000    164.000000
#
#              pixel5        pixel6        pixel7        pixel8        pixel9  \
# count  60000.000000  60000.000000  60000.000000  60000.000000  60000.000000
# mean       0.247967      0.411467      0.805767      2.198283      5.682000
# std        4.306912      5.836188      8.215169     14.093378     23.819481
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%        0.000000      0.000000      0.000000      0.000000      0.000000
# 50%        0.000000      0.000000      0.000000      0.000000      0.000000
# 75%        0.000000      0.000000      0.000000      0.000000      0.000000
# max      227.000000    230.000000    224.000000    255.000000    254.000000
#
#        ...      pixel775      pixel776      pixel777      pixel778  \
# count  ...  60000.000000  60000.000000  60000.000000  60000.000000
# mean   ...     34.625400     23.300683     16.588267     17.869433
# std    ...     57.545242     48.854427     41.979611     43.966032
# min    ...      0.000000      0.000000      0.000000      0.000000
# 25%    ...      0.000000      0.000000      0.000000      0.000000
# 50%    ...      0.000000      0.000000      0.000000      0.000000
# 75%    ...     58.000000      9.000000      0.000000      0.000000
# max    ...    255.000000    255.000000    255.000000    255.000000
#
#            pixel779      pixel780      pixel781      pixel782      pixel783  \
# count  60000.000000  60000.000000  60000.000000  60000.000000  60000.000000
# mean      22.814817     17.911483      8.520633      2.753300      0.855517
# std       51.830477     45.149388     29.614859     17.397652      9.356960
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%        0.000000      0.000000      0.000000      0.000000      0.000000
# 50%        0.000000      0.000000      0.000000      0.000000      0.000000
# 75%        0.000000      0.000000      0.000000      0.000000      0.000000
# max      255.000000    255.000000    255.000000    255.000000    255.000000
#
#           pixel784
# count  60000.00000
# mean       0.07025
# std        2.12587
# min        0.00000
# 25%        0.00000
# 50%        0.00000
# 75%        0.00000
# max      170.00000
#
# [8 rows x 785 columns]

# %%
train_df.label.unique()
# Out:
# array([2, 9, 6, 0, 3, 4, 5, 8, 7, 1], dtype=int64)

# %% [markdown]
# #### Each row represents an grayscale image containing 784 pixels and each pixel having values in range from 0-255
# #### The column label is a discrete value in the range 0 to 9 each value representing a specific category

# %%
class_names = ['T-shirt/top', 'Trouser', 'Pullover', 'Dress', 'Coat','Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle boot']

# %% [markdown]
# ### Preprocess Data
# Convert each image of 784 into (28x28x1)(height x width x color_channels). Divide values by 255 to scale the values.

# %%
x_train = train_df.iloc[:,1:].to_numpy()
x_train = x_train.reshape([-1,28,28,1])
x_train = x_train / 255

# %%
y_train = train_df.iloc[:,0].to_numpy()

# %%
x_test = test_df.iloc[:,1:].to_numpy()
x_test = x_test.reshape([-1,28,28,1])
x_test = x_test / 255

# %%
y_test = test_df.iloc[:,0].to_numpy()

# %% [markdown]
# ### Visualization

# %%
plt.figure(figsize=(10,10))
for i in range(25):
    plt.subplot(5,5,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(x_train[i], cmap=plt.cm.binary)
    plt.xlabel(class_names[y_train[i]])
plt.show()

# %% [markdown]
# ### Model Building

# %%
from keras.models import Sequential
from keras.layers import Dense,Conv2D,Flatten,MaxPooling2D,Dropout
# Out:
# WARNING:tensorflow:From C:\Users\adity\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
model = Sequential()

model.add(Conv2D(filters=64,kernel_size=(3,3),input_shape=(28,28,1),activation='relu'))
model.add(MaxPooling2D(pool_size = (2,2)))
model.add(Dropout(rate=0.3))
model.add(Flatten())
model.add(Dense(units=32, activation='relu'))
model.add(Dense(units=10, activation='sigmoid'))
model.compile(loss='sparse_categorical_crossentropy',optimizer='adam',metrics=['accuracy'])
model.summary()
# Out:
# WARNING:tensorflow:From C:\Users\adity\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From C:\Users\adity\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\layers\pooling\max_pooling2d.py:161: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# WARNING:tensorflow:From C:\Users\adity\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\optimizers\__init__.py:309: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 26, 26, 64)        640
#
#  max_pooling2d (MaxPooling2  (None, 13, 13, 64)        0
#  D)
#
#  dropout (Dropout)           (None, 13, 13, 64)        0
#
#  flatten (Flatten)           (None, 10816)             0
#
#  dense (Dense)               (None, 32)                346144
#
#  dense_1 (Dense)             (None, 10)                330
#
# =================================================================
# Total params: 347114 (1.32 MB)
# Trainable params: 347114 (1.32 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model.fit(x_train,y_train,epochs=50,batch_size=1200,validation_split=0.05)
# Out:
# Epoch 1/50
# WARNING:tensorflow:From C:\Users\adity\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# WARNING:tensorflow:From C:\Users\adity\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# 48/48 [==============================] - 19s 352ms/step - loss: 0.9282 - accuracy: 0.6777 - val_loss: 0.5581 - val_accuracy: 0.8047
# Epoch 2/50
# 48/48 [==============================] - 17s 353ms/step - loss: 0.4939 - accuracy: 0.8264 - val_loss: 0.4566 - val_accuracy: 0.8410
# Epoch 3/50
# 48/48 [==============================] - 16s 328ms/step - loss: 0.4235 - accuracy: 0.8526 - val_loss: 0.4219 - val_accuracy: 0.8540
# Epoch 4/50
# 48/48 [==============================] - 16s 327ms/step - loss: 0.3874 - accuracy: 0.8650 - val_loss: 0.3931 - val_accuracy: 0.8610
# Epoch 5/50
# 48/48 [==============================] - 16s 332ms/step - loss: 0.3630 - accuracy: 0.8736 - val_loss: 0.3581 - val_accuracy: 0.8727
# Epoch 6/50
# 48/48 [==============================] - 17s 351ms/step - loss: 0.3469 - accuracy: 0.8789 - val_loss: 0.3470 - val_accuracy: 0.8797
# Epoch 7/50
# 48/48 [==============================] - 17s 353ms/step - loss: 0.3342 - accuracy: 0.8830 - val_loss: 0.3367 - val_accuracy: 0.8810
# Epoch 8/50
# 48/48 [==============================] - 17s 356ms/step - loss: 0.3231 - accuracy: 0.8872 - val_loss: 0.3443 - val_accuracy: 0.8783
# Epoch 9/50
# 48/48 [==============================] - 17s 359ms/step - loss: 0.3097 - accuracy: 0.8914 - val_loss: 0.3183 - val_accuracy: 0.8867
# Epoch 10/50
# 48/48 [==============================] - 17s 357ms/step - loss: 0.3019 - accuracy: 0.8932 - val_loss: 0.3230 - val_accuracy: 0.8840
# Epoch 11/50
# 48/48 [==============================] - 16s 325ms/step - loss: 0.2950 - accuracy: 0.8964 - val_loss: 0.3057 - val_accuracy: 0.8930
# Epoch 12/50
# 48/48 [==============================] - 16s 325ms/step - loss: 0.2858 - accuracy: 0.8989 - val_loss: 0.2969 - val_accuracy: 0.8943
# Epoch 13/50
# 48/48 [==============================] - 16s 327ms/step - loss: 0.2796 - accuracy: 0.9017 - val_loss: 0.3033 - val_accuracy: 0.8923
# Epoch 14/50
# 48/48 [==============================] - 16s 327ms/step - loss: 0.2779 - accuracy: 0.9015 - val_loss: 0.2921 - val_accuracy: 0.8977
# Epoch 15/50
# 48/48 [==============================] - 16s 327ms/step - loss: 0.2692 - accuracy: 0.9048 - val_loss: 0.2941 - val_accuracy: 0.8917
# Epoch 16/50
# 48/48 [==============================] - 16s 331ms/step - loss: 0.2637 - accuracy: 0.9069 - val_loss: 0.2799 - val_accuracy: 0.9027
# Epoch 17/50
# 48/48 [==============================] - 16s 340ms/step - loss: 0.2618 - accuracy: 0.9068 - val_loss: 0.2809 - val_accuracy: 0.9017
# Epoch 18/50
# 48/48 [==============================] - 20s 422ms/step - loss: 0.2537 - accuracy: 0.9084 - val_loss: 0.2776 - val_accuracy: 0.9030
# Epoch 39/50
# 48/48 [==============================] - 19s 396ms/step - loss: 0.1937 - accuracy: 0.9294 - val_loss: 0.2630 - val_accuracy: 0.9090
# Epoch 40/50
# 48/48 [==============================] - 20s 406ms/step - loss: 0.1910 - accuracy: 0.9315 - val_loss: 0.2540 - val_accuracy: 0.9177
# Epoch 41/50
# 48/48 [==============================] - 20s 409ms/step - loss: 0.1870 - accuracy: 0.9330 - val_loss: 0.2578 - val_accuracy: 0.9093
# Epoch 42/50
# 48/48 [==============================] - 19s 399ms/step - loss: 0.1861 - accuracy: 0.9339 - val_loss: 0.2551 - val_accuracy: 0.9123
# Epoch 43/50
# 48/48 [==============================] - 19s 400ms/step - loss: 0.1826 - accuracy: 0.9342 - val_loss: 0.2540 - val_accuracy: 0.9123
# Epoch 44/50
# 48/48 [==============================] - 19s 399ms/step - loss: 0.1818 - accuracy: 0.9354 - val_loss: 0.2554 - val_accuracy: 0.9133
# Epoch 45/50
# 48/48 [==============================] - 19s 401ms/step - loss: 0.1787 - accuracy: 0.9359 - val_loss: 0.2533 - val_accuracy: 0.9133
# Epoch 46/50
# 48/48 [==============================] - 20s 414ms/step - loss: 0.1763 - accuracy: 0.9361 - val_loss: 0.2546 - val_accuracy: 0.9153
# Epoch 47/50
# 48/48 [==============================] - 19s 402ms/step - loss: 0.1765 - accuracy: 0.9369 - val_loss: 0.2497 - val_accuracy: 0.9147
# Epoch 48/50
# 48/48 [==============================] - 19s 400ms/step - loss: 0.1731 - accuracy: 0.9377 - val_loss: 0.2503 - val_accuracy: 0.9167
# Epoch 49/50
# 48/48 [==============================] - 19s 395ms/step - loss: 0.1696 - accuracy: 0.9386 - val_loss: 0.2600 - val_accuracy: 0.9120
# Epoch 50/50
# 48/48 [==============================] - 19s 399ms/step - loss: 0.1716 - accuracy: 0.9375 - val_loss: 0.2524 - val_accuracy: 0.9163

# %% [markdown]
# ### Evaluation

# %%
evaluation = model.evaluate(x_test,y_test)
# Out:
# 313/313 [==============================] - 1s 4ms/step - loss: 0.2344 - accuracy: 0.9187

# %%
print(f"Accuracy: {evaluation[1]}")
# Out:
# Accuracy: 0.9186999797821045

# %%
y_probas = model.predict(x_test)
# Out:
# 313/313 [==============================] - 2s 4ms/step

# %%
y_pred = y_probas.argmax(axis=-1)

# %%
y_pred
# Out:
# array([0, 1, 6, ..., 8, 8, 1], dtype=int64)

# %%
plt.figure(figsize=(10,10),)
for i in range(25):
    plt.subplot(5,5,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(x_test[i], cmap=plt.cm.binary)
#     plt.xlabel(f"True Class:{y_test[i]}")
    plt.title(f"Pred:{class_names[y_pred[i]]}")
plt.show()

# %%
from sklearn.metrics import classification_report

# %%
num_classes = 10
class_names = ["class {}".format(i) for i in range(num_classes)]
cr = classification_report(y_test, y_pred, target_names=class_names)
print(cr)
# Out:
#               precision    recall  f1-score   support
#
#      class 0       0.85      0.87      0.86      1000
#      class 1       0.98      0.99      0.98      1000
#      class 2       0.88      0.87      0.87      1000
#      class 3       0.94      0.93      0.93      1000
#      class 4       0.88      0.89      0.89      1000
#      class 5       0.98      0.98      0.98      1000
#      class 6       0.78      0.76      0.77      1000
#      class 7       0.95      0.97      0.96      1000
#      class 8       0.97      0.98      0.98      1000
#      class 9       0.98      0.95      0.96      1000
#
#     accuracy                           0.92     10000
#    macro avg       0.92      0.92      0.92     10000
# weighted avg       0.92      0.92      0.92     10000
